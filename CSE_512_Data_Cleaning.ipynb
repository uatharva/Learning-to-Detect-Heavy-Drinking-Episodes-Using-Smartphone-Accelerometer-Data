# %%
from google.colab import drive
drive.mount('/content')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import datetime
import scipy
from scipy.stats import skew, kurtosis

# %%
import os
os.listdir('/content/drive/My Drive/CSE512Data/clean_tac')

base_path = '/content/drive/My Drive/CSE512Data/clean_tac'
my_dict = dict()
for file_path in os.listdir(base_path):
  resp_frame = pd.read_csv(base_path + '/'+ file_path)
  my_dict[file_path.split('_')[0]] = resp_frame

def get_tac_value(pid, t_value):
  ind = np.argmax(my_dict[pid]['timestamp'] > t_value)
  if ind != 0:
    ind = ind - 1
  return my_dict[pid].iloc[[ind]]['TAC_Reading'].values[0]

def spectral_centroid_spread(fft_magnitude, sampling_rate):
    """Computes spectral centroid of frame (given abs(FFT))"""
    ind = (np.arange(1, len(fft_magnitude) + 1)) * \
          (sampling_rate / (2.0 * len(fft_magnitude)))
    eps = 0.00000001
    Xt = fft_magnitude.copy()
    Xt = Xt / Xt.max()
    NUM = np.sum(ind * Xt)
    DEN = np.sum(Xt) + eps
 
    # Centroid:
    centroid = (NUM / DEN)
 
    # Spread:
    spread = np.sqrt(np.sum(((ind - centroid) ** 2) * Xt) / DEN)
 
    # Normalize:
    centroid = centroid / (sampling_rate / 2.0)
    spread = spread / (sampling_rate / 2.0)
 
    return centroid
def energy_entropy(frame, n_short_blocks):
    """Computes entropy of energy"""
    # total frame energy
    eps = 0.00000001
    for i in frame:
      frame_energy = np.sum(i ** 2)
    frame_length = len(frame)
    sub_win_len = int(np.floor(frame_length / n_short_blocks))
    if frame_length != sub_win_len * n_short_blocks:
        frame = frame[0:sub_win_len * n_short_blocks]
 
    # sub_wins is of size [n_short_blocks x L]
    sub_wins = frame.reshape(sub_win_len, n_short_blocks, order='F').copy()
 
    # Compute normalized sub-frame energies:
    s = np.sum(sub_wins ** 2, axis=0) / (frame_energy + eps)
 
    # Compute entropy of the normalized sub-frame energies:
    entropy = -np.sum(s * np.log2(s + eps))
    return entropy

def energy(frame):
  return np.sum(frame ** 2) / np.float64(len(frame))

# %%
def transform_frames(f, pid):
  cols = ['x', 'y', 'z']
  funcs = [('mean', np.mean), ('variance', np.var), ('median', np.median), ('min', np.min), ('max', np.max), ('rms', lambda x: np.sqrt(np.mean(np.square(x)))), ('energy_entropy', lambda x: energy_entropy(x, 10)), ('energy', energy), ('skew', skew), ('Kurtiosis', kurtosis)]
  fft_funcs = [('variance', np.var), ('spectral_centroid_spread', lambda x: spectral_centroid_spread(x, 40)) ]
  new_frame = pd.DataFrame()
  f['time_second'] = f['time'].apply(get_val)
  some_values = f.groupby('time_second')
  new_frame['TAC_reading'] = f.groupby('time_second')['x'].apply(np.array).index.to_series().apply(lambda x: get_tac_value(pid, x))
  for col in cols:
    col_array = some_values[col].apply(np.array)
    col_fft = col_array.apply(scipy.fft.fft)
    for key, func in funcs:
      print(pid,' :Working on', col, '   ', key)
      new_frame['_'.join([col, key])] = col_array.apply(func)
    for key, func in fft_funcs:
      print(pid,' :Working on', col, '   FFT ', key)
      new_frame['_'.join([col, 'FFT', key])] = col_fft.apply(func)
  new_frame['pid'] = pid
  print(new_frame.head())
  return new_frame

# %%
def get_time_value(x):
    t = datetime.datetime.fromtimestamp(x/1000.0)
    t = t.replace(microsecond = 0)
    return t.timestamp()
def get_time_ignore_second(x):
    t = datetime.datetime.fromtimestamp(x/1000.0)
    t = t.replace(microsecond = 0)
    t = t.replace(second = int(t.second / 10))
    return t.timestamp()
def get_window_10(x):
    t = datetime.datetime.fromtimestamp(x)
    t = t.replace(second = int(t.second / 10))
    return t.timestamp()

# %%
frame = pd.read_csv('/content/drive/My Drive/CSE512Data/all_accelerometer_data_pids_13.csv')
frame['window'] = frame['time'].apply(get_time_value)
frame['window10'] = frame['time'].apply(get_time_ignore_second)
frame['selected_window_10'] = frame['window'].apply(get_window_10)

# %%
funcs = [('mean', np.mean), ('variance', np.var), ('median', np.median), ('min', np.min), ('max', np.max), ('rms', lambda x: np.sqrt(np.mean(np.square(x)))), ('energy_entropy', lambda x: energy_entropy(x, 10)), ('energy', energy), ('skew', skew), ('Kurtiosis', kurtosis)]
fft_funcs = [('variance', np.var), ('spectral_centroid_spread', lambda x: spectral_centroid_spread(x, 40)) ]
cols = ['x', 'y', 'z']

# %%
look_up_frames = dict()
for pid in frame.pid.unique():
  response_frame = pd.DataFrame()
  grouped = frame[frame.pid == pid].groupby('window10')
  for col in cols:
    col_array = grouped[col].apply(np.array)
    col_fft = col_array.apply(scipy.fft.fft)
    for key, func in funcs:
      print(pid,' :Working on', col, '   ', key)
      response_frame['_'.join(['win_10', col, key])] = col_array.apply(func)
    for key, func in fft_funcs:
      print(pid,' :Working on', col, '   FFT ', key)
      response_frame['_'.join(['win_10', col, 'FFT', key])] = col_fft.apply(func)
  response_frame.pid = pid
  look_up_frames[pid] = response_frame
# Out:
# JB3156  :Working on x     mean
# JB3156  :Working on x     variance
# JB3156  :Working on x     median
# JB3156  :Working on x     min
# JB3156  :Working on x     max
# JB3156  :Working on x     rms
# JB3156  :Working on x     energy_entropy
# JB3156  :Working on x     energy
# JB3156  :Working on x     skew
# JB3156  :Working on x     Kurtiosis
# JB3156  :Working on x    FFT  variance
# JB3156  :Working on x    FFT  spectral_centroid_spread
# JB3156  :Working on y     mean
# JB3156  :Working on y     variance
# JB3156  :Working on y     median
# JB3156  :Working on y     min
# JB3156  :Working on y     max
# JB3156  :Working on y     rms
# JB3156  :Working on y     energy_entropy
# JB3156  :Working on y     energy
# JB3156  :Working on y     skew
# JB3156  :Working on y     Kurtiosis
# JB3156  :Working on y    FFT  variance
# JB3156  :Working on y    FFT  spectral_centroid_spread
# JB3156  :Working on z     mean
# JB3156  :Working on z     variance
# JB3156  :Working on z     median
# JB3156  :Working on z     min
# JB3156  :Working on z     max
# JB3156  :Working on z     rms
# JB3156  :Working on z     energy_entropy
# JB3156  :Working on z     energy
# JB3156  :Working on z     skew
# JB3156  :Working on z     Kurtiosis
# JB3156  :Working on z    FFT  variance
# JB3156  :Working on z    FFT  spectral_centroid_spread
# CC6740  :Working on x     mean
# CC6740  :Working on x     variance
# CC6740  :Working on x     median
# CC6740  :Working on x     min
# CC6740  :Working on x     max
# CC6740  :Working on x     rms
# CC6740  :Working on x     energy_entropy
# CC6740  :Working on x     energy
# CC6740  :Working on x     skew
# CC6740  :Working on x     Kurtiosis
# CC6740  :Working on x    FFT  variance
# CC6740  :Working on x    FFT  spectral_centroid_spread
# CC6740  :Working on y     mean
# CC6740  :Working on y     variance
# CC6740  :Working on y     median
# CC6740  :Working on y     min
# CC6740  :Working on y     max
# CC6740  :Working on y     rms
# CC6740  :Working on y     energy_entropy
# CC6740  :Working on y     energy
# CC6740  :Working on y     skew
# CC6740  :Working on y     Kurtiosis
# CC6740  :Working on y    FFT  variance
# CC6740  :Working on y    FFT  spectral_centroid_spread
# CC6740  :Working on z     mean
# CC6740  :Working on z     variance
# CC6740  :Working on z     median
# CC6740  :Working on z     min
# CC6740  :Working on z     max
# CC6740  :Working on z     rms
# CC6740  :Working on z     energy_entropy
# CC6740  :Working on z     energy
# CC6740  :Working on z     skew
# CC6740  :Working on z     Kurtiosis
# CC6740  :Working on z    FFT  variance
# CC6740  :Working on z    FFT  spectral_centroid_spread
# SA0297  :Working on x     mean
# SA0297  :Working on x     variance
# SA0297  :Working on x     median
# SA0297  :Working on x     min
# SA0297  :Working on x     max
# SA0297  :Working on x     rms
# SA0297  :Working on x     energy_entropy
# SA0297  :Working on x     energy
# SA0297  :Working on x     skew
# SA0297  :Working on x     Kurtiosis
# SA0297  :Working on x    FFT  variance
# SA0297  :Working on x    FFT  spectral_centroid_spread
# SA0297  :Working on y     mean
# SA0297  :Working on y     variance
# SA0297  :Working on y     median
# SA0297  :Working on y     min
# SA0297  :Working on y     max
# SA0297  :Working on y     rms
# SA0297  :Working on y     energy_entropy
# SA0297  :Working on y     energy
# SA0297  :Working on y     skew
# SA0297  :Working on y     Kurtiosis
# SA0297  :Working on y    FFT  variance
# SA0297  :Working on y    FFT  spectral_centroid_spread
# SA0297  :Working on z     mean
# SA0297  :Working on z     variance
# SA0297  :Working on z     median
# SA0297  :Working on z     min
# SA0297  :Working on z     max
# SA0297  :Working on z     rms
# SA0297  :Working on z     energy_entropy
# SA0297  :Working on z     energy
# SA0297  :Working on z     skew
# SA0297  :Working on z     Kurtiosis
# SA0297  :Working on z    FFT  variance
# SA0297  :Working on z    FFT  spectral_centroid_spread
# PC6771  :Working on x     mean
# PC6771  :Working on x     variance
# PC6771  :Working on x     median
# PC6771  :Working on x     min
# PC6771  :Working on x     max
# PC6771  :Working on x     rms
# PC6771  :Working on x     energy_entropy
# PC6771  :Working on x     energy
# PC6771  :Working on x     skew
# PC6771  :Working on x     Kurtiosis
# PC6771  :Working on x    FFT  variance
# PC6771  :Working on x    FFT  spectral_centroid_spread
# PC6771  :Working on y     mean
# PC6771  :Working on y     variance
# PC6771  :Working on y     median
# PC6771  :Working on y     min
# PC6771  :Working on y     max
# PC6771  :Working on y     rms
# PC6771  :Working on y     energy_entropy
# PC6771  :Working on y     energy
# PC6771  :Working on y     skew
# PC6771  :Working on y     Kurtiosis
# PC6771  :Working on y    FFT  variance
# PC6771  :Working on y    FFT  spectral_centroid_spread
# PC6771  :Working on z     mean
# PC6771  :Working on z     variance
# PC6771  :Working on z     median
# PC6771  :Working on z     min
# PC6771  :Working on z     max
# PC6771  :Working on z     rms
# PC6771  :Working on z     energy_entropy
# PC6771  :Working on z     energy
# PC6771  :Working on z     skew
# PC6771  :Working on z     Kurtiosis
# PC6771  :Working on z    FFT  variance
# PC6771  :Working on z    FFT  spectral_centroid_spread
# BK7610  :Working on x     mean
# BK7610  :Working on x     variance
# BK7610  :Working on x     median
# BK7610  :Working on x     min
# BK7610  :Working on x     max
# BK7610  :Working on x     rms
# BK7610  :Working on x     energy_entropy
# BK7610  :Working on x     energy
# BK7610  :Working on x     skew
# BK7610  :Working on x     Kurtiosis
# BK7610  :Working on x    FFT  variance
# BK7610  :Working on x    FFT  spectral_centroid_spread
# BK7610  :Working on y     mean
# BK7610  :Working on y     variance
# BK7610  :Working on y     median
# BK7610  :Working on y     min
# BK7610  :Working on y     max
# BK7610  :Working on y     rms
# BK7610  :Working on y     energy_entropy
# BK7610  :Working on y     energy
# BK7610  :Working on y     skew
# BK7610  :Working on y     Kurtiosis
# BK7610  :Working on y    FFT  variance
# BK7610  :Working on y    FFT  spectral_centroid_spread
# BK7610  :Working on z     mean
# BK7610  :Working on z     variance
# BK7610  :Working on z     median
# BK7610  :Working on z     min
# BK7610  :Working on z     max
# BK7610  :Working on z     rms
# BK7610  :Working on z     energy_entropy
# BK7610  :Working on z     energy
# BK7610  :Working on z     skew
# BK7610  :Working on z     Kurtiosis
# BK7610  :Working on z    FFT  variance
# BK7610  :Working on z    FFT  spectral_centroid_spread
# DC6359  :Working on x     mean
# DC6359  :Working on x     variance
# DC6359  :Working on x     median
# DC6359  :Working on x     min
# DC6359  :Working on x     max
# DC6359  :Working on x     rms
# DC6359  :Working on x     energy_entropy
# DC6359  :Working on x     energy
# DC6359  :Working on x     skew
# DC6359  :Working on x     Kurtiosis
# DC6359  :Working on x    FFT  variance
# DC6359  :Working on x    FFT  spectral_centroid_spread
# DC6359  :Working on y     mean
# DC6359  :Working on y     variance
# DC6359  :Working on y     median
# DC6359  :Working on y     min
# DC6359  :Working on y     max
# DC6359  :Working on y     rms
# DC6359  :Working on y     energy_entropy
# DC6359  :Working on y     energy
# DC6359  :Working on y     skew
# DC6359  :Working on y     Kurtiosis
# DC6359  :Working on y    FFT  variance
# DC6359  :Working on y    FFT  spectral_centroid_spread
# DC6359  :Working on z     mean
# DC6359  :Working on z     variance
# DC6359  :Working on z     median
# DC6359  :Working on z     min
# DC6359  :Working on z     max
# DC6359  :Working on z     rms
# DC6359  :Working on z     energy_entropy
# DC6359  :Working on z     energy
# DC6359  :Working on z     skew
# DC6359  :Working on z     Kurtiosis
# DC6359  :Working on z    FFT  variance
# DC6359  :Working on z    FFT  spectral_centroid_spread
# MC7070  :Working on x     mean
# MC7070  :Working on x     variance
# MC7070  :Working on x     median
# MC7070  :Working on x     min
# MC7070  :Working on x     max
# MC7070  :Working on x     rms
# MC7070  :Working on x     energy_entropy
# MC7070  :Working on x     energy
# MC7070  :Working on x     skew
# MC7070  :Working on x     Kurtiosis
# MC7070  :Working on x    FFT  variance
# MC7070  :Working on x    FFT  spectral_centroid_spread
# MC7070  :Working on y     mean
# MC7070  :Working on y     variance
# MC7070  :Working on y     median
# MC7070  :Working on y     min
# MC7070  :Working on y     max
# MC7070  :Working on y     rms
# MC7070  :Working on y     energy_entropy
# MC7070  :Working on y     energy
# MC7070  :Working on y     skew
# MC7070  :Working on y     Kurtiosis
# MC7070  :Working on y    FFT  variance
# MC7070  :Working on y    FFT  spectral_centroid_spread
# MC7070  :Working on z     mean
# MC7070  :Working on z     variance
# MC7070  :Working on z     median
# MC7070  :Working on z     min
# MC7070  :Working on z     max
# MC7070  :Working on z     rms
# MC7070  :Working on z     energy_entropy
# MC7070  :Working on z     energy
# MC7070  :Working on z     skew
# MC7070  :Working on z     Kurtiosis
# MC7070  :Working on z    FFT  variance
# MC7070  :Working on z    FFT  spectral_centroid_spread
# MJ8002  :Working on x     mean
# MJ8002  :Working on x     variance
# MJ8002  :Working on x     median
# MJ8002  :Working on x     min
# MJ8002  :Working on x     max
# MJ8002  :Working on x     rms
# MJ8002  :Working on x     energy_entropy
# MJ8002  :Working on x     energy
# MJ8002  :Working on x     skew
# MJ8002  :Working on x     Kurtiosis
# MJ8002  :Working on x    FFT  variance
# MJ8002  :Working on x    FFT  spectral_centroid_spread
# MJ8002  :Working on y     mean
# MJ8002  :Working on y     variance
# MJ8002  :Working on y     median
# MJ8002  :Working on y     min
# MJ8002  :Working on y     max
# MJ8002  :Working on y     rms
# MJ8002  :Working on y     energy_entropy
# MJ8002  :Working on y     energy
# MJ8002  :Working on y     skew
# MJ8002  :Working on y     Kurtiosis
# MJ8002  :Working on y    FFT  variance
# MJ8002  :Working on y    FFT  spectral_centroid_spread
# MJ8002  :Working on z     mean
# MJ8002  :Working on z     variance
# MJ8002  :Working on z     median
# MJ8002  :Working on z     min
# MJ8002  :Working on z     max
# MJ8002  :Working on z     rms
# MJ8002  :Working on z     energy_entropy
# MJ8002  :Working on z     energy
# MJ8002  :Working on z     skew
# MJ8002  :Working on z     Kurtiosis
# MJ8002  :Working on z    FFT  variance
# MJ8002  :Working on z    FFT  spectral_centroid_spread
# BU4707  :Working on x     mean
# BU4707  :Working on x     variance
# BU4707  :Working on x     median
# BU4707  :Working on x     min
# BU4707  :Working on x     max
# BU4707  :Working on x     rms
# BU4707  :Working on x     energy_entropy
# BU4707  :Working on x     energy
# BU4707  :Working on x     skew
# BU4707  :Working on x     Kurtiosis
# BU4707  :Working on x    FFT  variance
# BU4707  :Working on x    FFT  spectral_centroid_spread
# BU4707  :Working on y     mean
# BU4707  :Working on y     variance
# BU4707  :Working on y     median
# BU4707  :Working on y     min
# BU4707  :Working on y     max
# BU4707  :Working on y     rms
# BU4707  :Working on y     energy_entropy
# BU4707  :Working on y     energy
# BU4707  :Working on y     skew
# BU4707  :Working on y     Kurtiosis
# BU4707  :Working on y    FFT  variance
# BU4707  :Working on y    FFT  spectral_centroid_spread
# BU4707  :Working on z     mean
# BU4707  :Working on z     variance
# BU4707  :Working on z     median
# BU4707  :Working on z     min
# BU4707  :Working on z     max
# BU4707  :Working on z     rms
# BU4707  :Working on z     energy_entropy
# BU4707  :Working on z     energy
# BU4707  :Working on z     skew
# BU4707  :Working on z     Kurtiosis
# BU4707  :Working on z    FFT  variance
# BU4707  :Working on z    FFT  spectral_centroid_spread
# JR8022  :Working on x     mean
# JR8022  :Working on x     variance
# JR8022  :Working on x     median
# JR8022  :Working on x     min
# JR8022  :Working on x     max
# JR8022  :Working on x     rms
# JR8022  :Working on x     energy_entropy
# JR8022  :Working on x     energy
# JR8022  :Working on x     skew
# JR8022  :Working on x     Kurtiosis
# JR8022  :Working on x    FFT  variance
# JR8022  :Working on x    FFT  spectral_centroid_spread
# JR8022  :Working on y     mean
# JR8022  :Working on y     variance
# JR8022  :Working on y     median
# JR8022  :Working on y     min
# JR8022  :Working on y     max
# JR8022  :Working on y     rms
# JR8022  :Working on y     energy_entropy
# JR8022  :Working on y     energy
# JR8022  :Working on y     skew
# JR8022  :Working on y     Kurtiosis
# JR8022  :Working on y    FFT  variance
# JR8022  :Working on y    FFT  spectral_centroid_spread
# JR8022  :Working on z     mean
# JR8022  :Working on z     variance
# JR8022  :Working on z     median
# JR8022  :Working on z     min
# JR8022  :Working on z     max
# JR8022  :Working on z     rms
# JR8022  :Working on z     energy_entropy
# JR8022  :Working on z     energy
# JR8022  :Working on z     skew
# JR8022  :Working on z     Kurtiosis
# JR8022  :Working on z    FFT  variance
# JR8022  :Working on z    FFT  spectral_centroid_spread
# HV0618  :Working on x     mean
# HV0618  :Working on x     variance
# HV0618  :Working on x     median
# HV0618  :Working on x     min
# HV0618  :Working on x     max
# HV0618  :Working on x     rms
# HV0618  :Working on x     energy_entropy
# HV0618  :Working on x     energy
# HV0618  :Working on x     skew
# HV0618  :Working on x     Kurtiosis
# HV0618  :Working on x    FFT  variance
# HV0618  :Working on x    FFT  spectral_centroid_spread
# HV0618  :Working on y     mean
# HV0618  :Working on y     variance
# HV0618  :Working on y     median
# HV0618  :Working on y     min
# HV0618  :Working on y     max
# HV0618  :Working on y     rms
# HV0618  :Working on y     energy_entropy
# HV0618  :Working on y     energy
# HV0618  :Working on y     skew
# HV0618  :Working on y     Kurtiosis
# HV0618  :Working on y    FFT  variance
# HV0618  :Working on y    FFT  spectral_centroid_spread
# HV0618  :Working on z     mean
# HV0618  :Working on z     variance
# HV0618  :Working on z     median
# HV0618  :Working on z     min
# HV0618  :Working on z     max
# HV0618  :Working on z     rms
# HV0618  :Working on z     energy_entropy
# HV0618  :Working on z     energy
# HV0618  :Working on z     skew
# HV0618  :Working on z     Kurtiosis
# HV0618  :Working on z    FFT  variance
# HV0618  :Working on z    FFT  spectral_centroid_spread
# SF3079  :Working on x     mean
# SF3079  :Working on x     variance
# SF3079  :Working on x     median
# SF3079  :Working on x     min
# SF3079  :Working on x     max
# SF3079  :Working on x     rms
# SF3079  :Working on x     energy_entropy
# SF3079  :Working on x     energy
# SF3079  :Working on x     skew
# SF3079  :Working on x     Kurtiosis
# SF3079  :Working on x    FFT  variance
# SF3079  :Working on x    FFT  spectral_centroid_spread
# SF3079  :Working on y     mean
# SF3079  :Working on y     variance
# SF3079  :Working on y     median
# SF3079  :Working on y     min
# SF3079  :Working on y     max
# SF3079  :Working on y     rms
# SF3079  :Working on y     energy_entropy
# SF3079  :Working on y     energy
# SF3079  :Working on y     skew
# SF3079  :Working on y     Kurtiosis
# SF3079  :Working on y    FFT  variance
# SF3079  :Working on y    FFT  spectral_centroid_spread
# SF3079  :Working on z     mean
# SF3079  :Working on z     variance
# SF3079  :Working on z     median
# SF3079  :Working on z     min
# SF3079  :Working on z     max
# SF3079  :Working on z     rms
# SF3079  :Working on z     energy_entropy
# SF3079  :Working on z     energy
# SF3079  :Working on z     skew
# SF3079  :Working on z     Kurtiosis
# SF3079  :Working on z    FFT  variance
# SF3079  :Working on z    FFT  spectral_centroid_spread
# DK3500  :Working on x     mean
# DK3500  :Working on x     variance
# DK3500  :Working on x     median
# DK3500  :Working on x     min
# DK3500  :Working on x     max
# DK3500  :Working on x     rms
# DK3500  :Working on x     energy_entropy
# DK3500  :Working on x     energy
# DK3500  :Working on x     skew
# DK3500  :Working on x     Kurtiosis
# DK3500  :Working on x    FFT  variance
# DK3500  :Working on x    FFT  spectral_centroid_spread
# DK3500  :Working on y     mean
# DK3500  :Working on y     variance
# DK3500  :Working on y     median
# DK3500  :Working on y     min
# DK3500  :Working on y     max
# DK3500  :Working on y     rms
# DK3500  :Working on y     energy_entropy
# DK3500  :Working on y     energy
# DK3500  :Working on y     skew
# DK3500  :Working on y     Kurtiosis
# DK3500  :Working on y    FFT  variance
# DK3500  :Working on y    FFT  spectral_centroid_spread
# DK3500  :Working on z     mean
# DK3500  :Working on z     variance
# DK3500  :Working on z     median
# DK3500  :Working on z     min
# DK3500  :Working on z     max
# DK3500  :Working on z     rms
# DK3500  :Working on z     energy_entropy
# DK3500  :Working on z     energy
# DK3500  :Working on z     skew
# DK3500  :Working on z     Kurtiosis
# DK3500  :Working on z    FFT  variance
# DK3500  :Working on z    FFT  spectral_centroid_spread

# %%
final_frames = dict()
for pid in frame.pid.unique():
  response_frame = pd.DataFrame()
  grouped = frame[frame.pid == pid].groupby('window')
  for col in cols:
    col_array = grouped[col].apply(np.array)
    col_fft = col_array.apply(scipy.fft.fft)
    for key, func in funcs:
      print(pid,' :Working on', col, '   ', key)
      response_frame['_'.join([ col, key])] = col_array.apply(func)
    for key, func in fft_funcs:
      print(pid,' :Working on', col, '   FFT ', key)
      response_frame['_'.join([ col, 'FFT', key])] = col_fft.apply(func)
  response_frame['window10'] = grouped['window10'].apply(lambda x: x.unique().tolist()[0])
  response_frame['pid'] = pid
  response_frame['TAC_reading'] = response_frame.index.to_series().apply(lambda x: get_tac_value(pid, x))
  final_frames[pid] = (response_frame)
# Out:
# JB3156  :Working on x     mean
# JB3156  :Working on x     variance
# JB3156  :Working on x     median
# JB3156  :Working on x     min
# JB3156  :Working on x     max
# JB3156  :Working on x     rms
# JB3156  :Working on x     energy_entropy
# JB3156  :Working on x     energy
# JB3156  :Working on x     skew
# JB3156  :Working on x     Kurtiosis
# JB3156  :Working on x    FFT  variance
# JB3156  :Working on x    FFT  spectral_centroid_spread
# JB3156  :Working on y     mean
# JB3156  :Working on y     variance
# JB3156  :Working on y     median
# JB3156  :Working on y     min
# JB3156  :Working on y     max
# JB3156  :Working on y     rms
# JB3156  :Working on y     energy_entropy
# JB3156  :Working on y     energy
# JB3156  :Working on y     skew
# JB3156  :Working on y     Kurtiosis
# JB3156  :Working on y    FFT  variance
# JB3156  :Working on y    FFT  spectral_centroid_spread
# JB3156  :Working on z     mean
# JB3156  :Working on z     variance
# JB3156  :Working on z     median
# JB3156  :Working on z     min
# JB3156  :Working on z     max
# JB3156  :Working on z     rms
# JB3156  :Working on z     energy_entropy
# JB3156  :Working on z     energy
# JB3156  :Working on z     skew
# JB3156  :Working on z     Kurtiosis
# JB3156  :Working on z    FFT  variance
# JB3156  :Working on z    FFT  spectral_centroid_spread
# CC6740  :Working on x     mean
# CC6740  :Working on x     variance
# CC6740  :Working on x     median
# CC6740  :Working on x     min
# CC6740  :Working on x     max
# CC6740  :Working on x     rms
# CC6740  :Working on x     energy_entropy
# CC6740  :Working on x     energy
# CC6740  :Working on x     skew
# CC6740  :Working on x     Kurtiosis
# CC6740  :Working on x    FFT  variance
# CC6740  :Working on x    FFT  spectral_centroid_spread
# CC6740  :Working on y     mean
# CC6740  :Working on y     variance
# CC6740  :Working on y     median
# CC6740  :Working on y     min
# CC6740  :Working on y     max
# CC6740  :Working on y     rms
# CC6740  :Working on y     energy_entropy
# CC6740  :Working on y     energy
# CC6740  :Working on y     skew
# CC6740  :Working on y     Kurtiosis
# CC6740  :Working on y    FFT  variance
# CC6740  :Working on y    FFT  spectral_centroid_spread
# CC6740  :Working on z     mean
# CC6740  :Working on z     variance
# CC6740  :Working on z     median
# CC6740  :Working on z     min
# CC6740  :Working on z     max
# CC6740  :Working on z     rms
# CC6740  :Working on z     energy_entropy
# CC6740  :Working on z     energy
# CC6740  :Working on z     skew
# CC6740  :Working on z     Kurtiosis
# CC6740  :Working on z    FFT  variance
# CC6740  :Working on z    FFT  spectral_centroid_spread
# SA0297  :Working on x     mean
# SA0297  :Working on x     variance
# SA0297  :Working on x     median
# SA0297  :Working on x     min
# SA0297  :Working on x     max
# SA0297  :Working on x     rms
# SA0297  :Working on x     energy_entropy
# SA0297  :Working on x     energy
# SA0297  :Working on x     skew
# SA0297  :Working on x     Kurtiosis
# SA0297  :Working on x    FFT  variance
# SA0297  :Working on x    FFT  spectral_centroid_spread
# SA0297  :Working on y     mean
# SA0297  :Working on y     variance
# SA0297  :Working on y     median
# SA0297  :Working on y     min
# SA0297  :Working on y     max
# SA0297  :Working on y     rms
# SA0297  :Working on y     energy_entropy
# SA0297  :Working on y     energy
# SA0297  :Working on y     skew
# SA0297  :Working on y     Kurtiosis
# SA0297  :Working on y    FFT  variance
# SA0297  :Working on y    FFT  spectral_centroid_spread
# SA0297  :Working on z     mean
# SA0297  :Working on z     variance
# SA0297  :Working on z     median
# SA0297  :Working on z     min
# SA0297  :Working on z     max
# SA0297  :Working on z     rms
# SA0297  :Working on z     energy_entropy
# SA0297  :Working on z     energy
# SA0297  :Working on z     skew
# SA0297  :Working on z     Kurtiosis
# SA0297  :Working on z    FFT  variance
# SA0297  :Working on z    FFT  spectral_centroid_spread
# PC6771  :Working on x     mean
# PC6771  :Working on x     variance
# PC6771  :Working on x     median
# PC6771  :Working on x     min
# PC6771  :Working on x     max
# PC6771  :Working on x     rms
# PC6771  :Working on x     energy_entropy
# PC6771  :Working on x     energy
# PC6771  :Working on x     skew
# PC6771  :Working on x     Kurtiosis
# PC6771  :Working on x    FFT  variance
# PC6771  :Working on x    FFT  spectral_centroid_spread
# PC6771  :Working on y     mean
# PC6771  :Working on y     variance
# PC6771  :Working on y     median
# PC6771  :Working on y     min
# PC6771  :Working on y     max
# PC6771  :Working on y     rms
# PC6771  :Working on y     energy_entropy
# PC6771  :Working on y     energy
# PC6771  :Working on y     skew
# PC6771  :Working on y     Kurtiosis
# PC6771  :Working on y    FFT  variance
# PC6771  :Working on y    FFT  spectral_centroid_spread
# PC6771  :Working on z     mean
# PC6771  :Working on z     variance
# PC6771  :Working on z     median
# PC6771  :Working on z     min
# PC6771  :Working on z     max
# PC6771  :Working on z     rms

# %%
final_frame = pd.DataFrame()
for key in final_frames:
  val = final_frames[key].copy()
  val.reset_index(drop= True, inplace= True)
  final_frame = pd.concat([final_frame, val])

# %%
good = final_frame.dropna()

# %%
good.to_csv('/content/drive/My Drive/CSE512Data/good_again_bhas.csv')

# %%
wow = pd.DataFrame()
for key in final_frames:
  val1 = final_frames[key].copy()
  val1 = val1.reset_index(drop= True)
  val2 = look_up_frames[key].copy().reset_index()
  wow = pd.concat([wow, pd.merge(val1, val2, how='inner', on = 'window10')])
wow = wow.dropna()

# %%
wow.to_csv('/content/drive/My Drive/CSE512Data/mega3.csv')
